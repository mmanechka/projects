# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Итак, мои комментарии на этот раз будут зелёными, в заголовке иметь версию V2 (как у этого!) и в них я буду стараться ответить на твои вопросы, если таковые увижу (мелкие/"проходные" изменения/исправления в тексте проекта, каждое из них, не буду с твоего позволения комментировать - только те моменты, где я что-то более-менее не банальное могу сказать. Хорошо? Будем считать, что, если комментария на твое исправление нет - значит я согласен с тобой в этом пункте).
#
# ………………
#
# Я вижу, что все красные комментарии учтены, код исправлен, выводы актуализированы. Соответственно никаких вопросов/моментов/комментариев, мешающих принять твой проект у меня более нет.
#
# ПРОЕКТ ПРИНЯТ!
#
# Я же в свою очередь, ниже попытался ответить на все твои вопросы (если видел, что они есть).
#
# Желаю тебе успехов в учёбе, желаю, чтобы проекты сдавались или сразу, или после первой итерации! Удачи!
#
# p.s. я тебе на твой адрес эл/почты сейчас вышлю некоторые материалы из своей электронной библиотеки - надеюсь они будут тебе полезными в учёбе.</div>

# %% [markdown]
# Приветствую коллега!
#
# Меня зовут Александр Непомнящий и я буду проверять твой проект. Предлагаю общаться на «ты» :))) Но, если это не удобно - мы вполне можем перейти на вы".
#
# Вкратце обо мне: я работаю в сфере информационных технологий, аналитика (анализ) данных - это и мой рабочий функционал и личная, интересная мне область для саморазвития. Используемый стек: python, pandas, графические библиотеки matplotlib/seaborn/plotly. Сфера применения: маркетинговая аналитика в медицинской клинике (Клиника «Кивач», www.kivach.ru, республика Карелия). Если вдруг есть вопрос – что делает аналитик в коммерческой медицине – то вот короткий ответ. Самый главный вопрос, на который мы хотим получить ответ (и который в дальнейшем приведёт к перераспределению рекламного бюджета, плюс напрямую повлияет на разработку и предложению рынку новых лечебных программ) - это КТО ОН, НАШ КЛИЕНТ? Фактически это задача (на нашем внутреннем языке формулируется как построение и анализ «ПОРТРЕТА КЛИЕНТА»). Визуализируем и пытаемся придать смысл половозрастным данным наших клиентов, кто из какого региона и в какие времена года к нам приезжает. Учитываем количество приездов. Учитываем на какую программу этот конкретный клиент приехал в первый раз и как в дальнейшем меняются его предпочтения. Пытаемся построить модель оттока и спрогнозировать, когда клиент уйдёт в отток. Смотрим цифры (суммы трат клиентов на отдельных группах медицинских программ). Анализируем медицинские услуги, которые входят в путёвку, а также что, в каких количествах и на какую сумму клиент покупает дополнительно. Очень вкратце как-то так.
#
# Теперь к сути: основная цель моей проверки - пройти по шагам, по логике твоего решения и обсудить те моменты, которые можно изменить, улучшить, довести до идеала. Такой формат работы двух программистов (аналитиков) ты или уже встречал(а), или встретишь на своей новой работе. Кто-то такой процесс называет "код-ревью", ну а как по мне, так это обмен опытом двух коллег, когда каждый из нас становиться лучше в процессе дискуссии.
#
# Свои мысли, советы, комментарии и вопросы я буду оставлять в текстовых ячейках (markdown) ПОД твоим кодом.
# Для твоего удобства все эти заметки будут "цветными", как на примерах ниже:
#
# "Зелеными" комментариями я буду отмечать твой элегантный ("красивый") код и/или удачные решения, на которые ты можешь смело опираться в будущих проектах.
# <div class="alert alert-success">
# <b>Отлично! 👍</b>
#
# Отличная находка, элегантный код ...</div>
#
# "Жёлтые" комментарии - это мои размышления, предложения, что-то, что на следующей итерации можно сделать по-другому. Твоя реакция на "жёлтые" комментарий необходима и подразумевает или правки, или реакцию или аргументированное согласие/не согласие. Я искренне верю, что наш двусторонний диалог под "желтым" комментарием - это то, от чего твой проект только выиграет. <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Здесь я бы предложил использовать .... Мои аргументы в пользу этого ...</div>
#
# "Красные" комментарий будут появляться, когда что-то пойдёт не так: например, код будет выдавать ошибку. Или, когда в проекте не будет ответов на основные вопросы, ради которых весь анализ и выполнялся. "Красные" комментарии необходимо будет исправить, прежде чем я смогу принять проект.
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# В этой ячейке код работает не так как задумано ...</div>
#
# Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии. Это поможет мне оперативно выполнить повторную проверку твоего проекта.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом, лучше всего в новой ячейке, сразу под моим комментарием. Если для своих комментариев ты будешь использовать какой-то заметный цвет, то мне будет легче отследить твои изменения, например так:
#
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Текст твоего комментария ...</font>
# </div>
#
# Ну и наконец информируй меня в том случае, если по твоему проекту подходит дедлайн! В таком случае я приложу усилия, чтобы ты сдал(а) его вовремя; буду оперативно, в приоритете проверять итерации ревью, а также отвечать на твои вопросы, если этого будет требовать ситуация.
#
# **Распространенные типичные недочёты в проектах студентов:**
#
# <div class="alert alert-danger" ❌>
# Неработоспособный код. Проверь проект на работоспособность перед отправкой на проверку. Это важный навык, который тебе пригодится как на собеседовании, при выполнении тестового задания, так и перед совещанием у руководства компании.</div>
#
# <div class="alert alert-danger" ❌>
# Проект не структурирован. В проекте должна быть структура, т.е. названия разделов и подразделов должны быть записаны в ячейках Markdown.</div>
#
# <div class="alert alert-warning" 👉 >
# Отсутствие описания, целей проекта, его задач, выводов. В описании должны быть озвучены поставленные задачи, содержание датасета, промежуточные и финальные выводы. Как правило, заказчик читает только финальный вывод, поэтому важно добавить информацию о проведенном исследовании, применить форматирование текста, в общем, сделать красиво, чтобы было понятно, что проведено настоящее исследование и выводу можно верить.</div>
#
# <div class="alert alert-warning" 👉 >
# "Длинный код". Код и и комментарии, которые прячутся за правым концом ячейки нужно переносить на новую строку. Твои будущие коллеги не оценят необходимость постоянного скроллинга. Согласно PEP8: https://www.python.org/dev/peps/pep-0008/ длина строки не должна превышать 79 символов.</div>
#
# <div class="alert alert-warning" 👉 >
# Твои коллеги ценят и твое и своё время, поэтому "подсвечивай" свои комментарии в ячейках Markdown. Подробнее про синтаксис Markdown, с примерами, можно почитать здесь: https://paulradzkov.com/2014/markdown_cheatsheet/?</div>

# %% [markdown]
#  ## <font color='indigo'>Сборный проект №1</font>

# %% [markdown]
# ### <font color='green'>Получение данных и их просмотр:</font>

# %% [markdown]
# <font color='navy'> - Просмотр входных данных и работа с ними: удаление дубликатов, пропусков. \
#     - Поиск аномальных значений \
#     - Предварительные выводы о собранных данных </font>

# %% [markdown]
# ### <font color='green'>Обработка данных:</font>

# %% [markdown]
# <font color='navy'> - Найти и обработать пропуски \
#     - Поработать с дубликатами (если они есть) \
#     - Удалить пропуски, где это возможно \
#     - Заменить названия столбцов\
#     - Преобразовать данные в нужные типы \
#     - Обработка значения 'tbd'\
#     - Посчитать суммарные продажи во всех регионах
# </font>

# %% [markdown]
# ### <font color='green'>Вопросы исследования</font>

# %% [markdown]
# <font color='navy'> - Какова динамика выпуска игр по разным годам? Важны ли все периоды? \
#     - Как меняются продажи по разным платформам? \
#     - Удалить пропуски, где это возможно \
#     - Какие платформы лидируют по продажам, растут или падают? Какие платформы потенциально прибыльны?\
#     - Как распределяются продажи в зависимости от платформы (ящик с усами)? \
#     - Как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков?\
#     - Какие самые прибыльные жанры? Выделяются ли жанры с высокими и низкими продажами?
# </font>

# %% [markdown]
# ### <font color='green'>Результаты исследования</font>

# %% [markdown]
# <font color='navy'> - Выводы\
#     - Рекомендации </font>

# %% [markdown]
# #### <font color='indigo'> Описание данных </font>
# Name — название игры\
# Platform — платформа\
# Year_of_Release — год выпуска\
# Genre — жанр игры\
# NA_sales — продажи в Северной Америке (миллионы проданных копий)\
# EU_sales — продажи в Европе (миллионы проданных копий)\
# JP_sales — продажи в Японии (миллионы проданных копий)\
# Other_sales — продажи в других странах (миллионы проданных копий)\
# Critic_Score — оценка критиков (максимум 100)\
# User_Score — оценка пользователей (максимум 10)\
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию\
# Данные за 2016 год могут быть неполными.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
try:
    df = pd.read_csv('/Users/temp/Desktop/projects/games.csv')
except:
    df = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Здесь хорошо! При такой загрузке данных и тебе комфортно работать с проектом на домашнем ПК и у меня всё ОК во время проверки проекта в Юпитер Хабе</div>

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# Приведём к "змеиному регистру" все заголовки

# %%
df.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# В user_score должны быть числовые данные.

# %%
df['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %% [markdown]
# Попробуем понять, что за странное tbd

# %%
df[df['user_score'] == 'tbd'].count()
# Out:
# name               2424
# platform           2424
# year_of_release    2376
# genre              2424
# na_sales           2424
# eu_sales           2424
# jp_sales           2424
# other_sales        2424
# critic_score       1082
# user_score         2424
# rating             2374
# dtype: int64

# %%
df[df['user_score'] == 'tbd'].sample(5)
# Out:
#                             name platform  year_of_release    genre  na_sales  \
# 11185                   Bionicle      GBA           2003.0   Action      0.06
# 9403                     NHL 2K9      PS3           2008.0   Sports      0.11
# 14130  Greg Hastings Paintball 2      PS3           2010.0  Shooter      0.03
# 6231          NCAA Basketball 09      PS2           2008.0   Sports      0.14
# 15360                Kill.Switch      GBA           2004.0  Shooter      0.02
#
#        eu_sales  jp_sales  other_sales  critic_score user_score rating
# 11185      0.02       0.0         0.00           NaN        tbd      E
# 9403       0.01       0.0         0.01          70.0        tbd   E10+
# 14130      0.00       0.0         0.00          46.0        tbd   E10+
# 6231       0.11       0.0         0.04          55.0        tbd      E
# 15360      0.01       0.0         0.00           NaN        tbd      T

# %% [markdown]
# Из определения: \
# TBD - аббревиатура от английского To Be Determined (будет определено) или To Be Decided (будет решено). Используется, если какая-то информация еще не определена или решение по вопросу не принято.\
# То есть база как-то обновляется и оценка не может быть дана. Заменить это на значение будет некорректно, поэтому можно заменить это на пропуск.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# То, что ты tbd меняешь на NaN - это правильно. По сути это и есть пропуски (строки с играми, для которых оценка не проставлена, пропущена по каким-то причинам).</div>

# %%
df.loc[df['user_score'] == 'tbd','user_score'] = np.nan

# %%
df['user_score'] = df['user_score'].astype(float)

# %%
df['user_score'].sample()
# Out:
# 7455    7.7
# Name: user_score, dtype: float64

# %% [markdown]
# Теперь у нас числовое значение в этом столбце.

# %%
df.describe()
# Out:
#        year_of_release      na_sales      eu_sales      jp_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         other_sales  critic_score   user_score
# count  16715.000000   8137.000000  7590.000000
# mean       0.047342     68.967679     7.125046
# std        0.186731     13.938165     1.500006
# min        0.000000     13.000000     0.000000
# 25%        0.000000     60.000000     6.400000
# 50%        0.010000     71.000000     7.500000
# 75%        0.030000     79.000000     8.200000
# ...

# %% [markdown]
# Видим, что по продажам есть аномально высокие - 41, 28 и 10 млн. Пока непонятно, что с ними делать. Возможно, есть правда очень большие продажи игр (какие-нибудь игры, которые имеют высокую популярность).

# %%
pd.DataFrame(round(df.isna().mean(),5)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_2a51e_row0_col0,#T_2a51e_row1_col0,#T_2a51e_row3_col0,#T_2a51e_row4_col0,#T_2a51e_row5_col0,#T_2a51e_row6_col0,#T_2a51e_row7_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_2a51e_row2_col0{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_2a51e_row8_col0{
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }#T_2a51e_row9_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_2a51e_row10_col0{
#             background-color:  #f59d7e;
#             color:  #000000;
#         }</style><table id="T_2a51e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2a51e_level0_row0" class="row_heading level0 row0" >name</th>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Это хорошо! "Отображение" пропусков в процентах воспринимается проще и нагляднее, чем в абсолютных единицах.</div>

# %% [markdown]
# Большое число пропусков в стобце оценки критиков 51%, в стоблце оценки пользователей 40% и в рейтинге игры 40%. Причина, возможно, очень проста: на какие-то игры критики и пользователи не оставляли свой отзыв. Поэтому отсуствие оценок можно заменить на -1 (так как оценка ноль это тоже оценка по шкале - это видно из минимального значения по user_score в таблице describe), а в рейтинг добавить отдельную группу для таких игр - no_reting

# %%
df['user_score'] = df['user_score'].fillna(-1)
df['critic_score'] = df['critic_score'].fillna(-1)
df['rating'] = df['rating'].fillna('no_rating')

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Один из ключевых моментов этого проекта: ты пропуски в 2 столбцах с оценками ('critic_score' и 'user_score') заполняешь «заглушкой». Это ОК здесь. Но дальше, когда мы будем строить корреляции, а также возможно оценивать платформы в зависимости от оценок (пользователей / экспертов) - надо будет вспомнить этот момент ... Если не вспомнишь и не обработаешь, то дальше скорее всего будет ошибка в результатах анализа, в графиках и в твоих выводах.
#
# Отметь этот момент - возможно нам придется вернуться сюда.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Да, так и сделала :)</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Отлично )
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Отлично, принято правильное решение! «Заглушка» для NaN значений в столбце ‘rating’ – это верное решение в этом проекте. Далее, когда ты будешь анализировать особенности регионов в зависимости от рейтинга ESRB, то увидишь, что если бы они остались NaN, то на графиках их не было бы видно, также такие игры "выпали" бы из анализа и выводов, а это красная ошибка в этом проекте.</div>

# %% [markdown]
# Также есть пропуски в названиях и жанре. По сути это не будет влиять, например, на продажи игр - название и жанр у них может быть любой. Поэтому назвать мы их можем как хотим: просто это будет отдельная группа - без названий и жанров.

# %%
df['genre'] = df['genre'].fillna('no_genre')
df['name'] = df['name'].fillna('no_name')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-warning">
# <b>Предложение 👉</b>
#
# **df.duplicated().sum() == 0** не означает, что в данных нет дубликатов (записей).
#
# В реальных рабочих датасетах скорее всего не будет полных дубликатов, но вот неявные наверняка будут встречаться, соответственно с ними надо будет уметь работать. Попробуй найти неявные дубликаты (нужно использовать параметр **subset**). Ну а в нашем учебном проекте пробуй найти дубликаты для пары "Имя - Игровая консоль".
#
# Как их планируешь и планируешь ли обрабатывать?</div>

# %% [markdown]
# Явных дубликатов нет.

# %%
dup = df.duplicated(subset=["name", "platform"])
dup.sum()
# Out:
# 5

# %%
df[dup == True]
# Out:
#                               name platform  year_of_release     genre  \
# 1591   Need for Speed: Most Wanted     X360           2005.0    Racing
# 4127            Sonic the Hedgehog      PS3              NaN  Platform
# 11715  Need for Speed: Most Wanted       PC           2012.0    Racing
# 14244                      no_name      GEN           1993.0  no_genre
# 16230                Madden NFL 13      PS3           2012.0    Sports
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 1591        1.0      0.13      0.02         0.10          83.0         8.5
# 4127        0.0      0.48      0.00         0.00          43.0         4.1
# 11715       0.0      0.06      0.00         0.02          82.0         8.5
# 14244       0.0      0.00      0.03         0.00          -1.0        -1.0
# 16230       0.0      0.01      0.00         0.00          83.0         5.5
#
#           rating
# 1591           T
# 4127        E10+
# 11715          T
# ...

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Думаю, что неявные дубликаты можно удалить. Тем более их количество всего 5, что не повляиет на исследование. </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Отлично, верно! После анализа дубликатов вполне может быть принято решение их не обрабатывать/не удалять/ещё что-то, но пропускать сам шаг поиска (неявных) дублей не стоит (это один из обязательных шагов в пайплайне EDA).
# </div>

# %%
df = df.loc[~dup]

# %%
dup = df.duplicated(subset=["name", "platform"])
dup.sum()
# Out:
# 0

# %%
df['sales_total'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df ['other_sales']

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Ещё такой вариант суммирования есть (просто как альтернатива … **псевдокод**): **data[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis='columns')** и "присвоить" этот результат новому столбцу в **data**.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Хорошо, буду иметь ввиду </font>
# </div>

# %% [markdown]
# Подсчитали суммарные продаж во всех регионах и записали их в отдельный столбец.

# %%
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score     rating  \
# 0     28.96      3.77         8.45          76.0         8.0          E
# 1      3.58      6.81         0.77          -1.0        -1.0  no_rating
# 2     12.76      3.79         3.29          82.0         8.3          E
# 3     10.93      3.28         2.95          80.0         8.0          E
# 4      8.89     10.22         1.00          -1.0        -1.0  no_rating
#
#    sales_total
# 0        82.54
# 1        40.24
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Меня смущает отсутствие полноценного вывода в этом разделе, например, с описанием того что здесь делали? Зачем делали? Какие результаты получили? Что будем делать с этими результатами?
#
# Нужно больше слов, больше выводов, больше размышлений. Аналитика данных - это скорее "про выводы по данным", нежели чем про "про написание кода". Нет, программирование конечно в аналитике тоже занимает большой % времени, но построение выводов, уточнение формулировок и подготовка презентаций (например в PowerPoint) тоже значительную часть анализа занимает. И уж точно финальный вывод есть одна из главных составляющих качественной работы отличного аналитика данных.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Данные загружены, отлично.
#
# Хорошо, что применяешь метод .head()/.sample() таким образом в память не будет загружен весь датасет, объем которого может быть огромным.
#
# Методы .info, .describe, .value_counts(), .unique() как правило часто встречаются и обязательны к применению в задачах по исследованию данных, ведь с их помощью можно получить первые инсайты.
#
# Итак, мы провели предварительный анализ данных, проверили данные на наличие пропусков и затем обработали их (аргументированно заполнили / удалили / оставили как есть). Теперь можно приступать собственно к анализу данных и ответам на вопросы проекта.</div>

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
df['year_of_release'].hist(figsize = (5,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Агрегация по count() при построении гистограммы покажет нам число игр, выпущенных на всех платформах, в разрезе лет. Т.е. если одна и та же игра (name) вышла в некоем году на одной платформе, агрегат == 1. Если на 2-х платформах, агрегат == 2, ну и так далее. У меня вопрос к тебе – что в твоем случае, в написанном тобой коде мы считаем выпуском игры (в этом, некоем году)?
#
# Возможно, чтобы получить истинное количество «игр по годам» нам следует поискать дубликаты (используя subset по (Годам - Названиям игр) и затем исключить из полного датафрейма все дубли за исключением одной, «первой», строки? Как ты считаешь?</div>

# %%
name_year = df.drop_duplicates(subset=['name', 'year_of_release'], keep='first')

# %% [markdown]
# Проверим это по любой игре.

# %%
name_year.query('name == "Need for Speed: Most Wanted"')
# Out:
#                              name platform  year_of_release   genre  na_sales  \
# 253   Need for Speed: Most Wanted      PS2           2005.0  Racing      2.03
# 523   Need for Speed: Most Wanted      PS3           2012.0  Racing      0.71
# 6273  Need for Speed: Most Wanted     WiiU           2013.0  Racing      0.13
#
#       eu_sales  jp_sales  other_sales  critic_score  user_score     rating  \
# 253       1.79      0.08         0.47          82.0         9.1          T
# 523       1.46      0.06         0.58          -1.0        -1.0  no_rating
# 6273      0.12      0.00         0.02          -1.0        -1.0  no_rating
#
#       sales_total
# 253          4.37
# 523          2.81
# 6273         0.27

# %%
name_year['year_of_release'].hist(bins = 35, figsize=[15, 10])
plt.title('Динамика выпуска игр за 1980-2016 гг.')
plt.xlabel('Год')
plt.ylabel('Количество выпущенных игр')
plt.show()

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>После удаления игр, выпущенных в один и тот же год, но на разных платформах, мы получили реальную картину выпуска игр по годам. Мы видим, что выпуск игр постепенно растёт до 2007-2008 года,потом наступает пик выпуска игр, а после где-то с 2010 года идет тренд на снижение.Также добавила здесь название графика и подписи осей.</font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Хорошо, верно всё здесь.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Этот график, как и все прочие ниже, выиграли бы если бы были подписаны сами (plt.title), а также оси X и Y (plt.xlabel и plt.ylabel, соответственно), а также указаны единицы измерения по осям.
#
# Здорово, что есть объяснение поведения данного графика. Пытаться понять полученный результат - важная часть работы аналитика.
#
# p.s. построй график крупнее (используй например **figsize=[20, 10]**)</div>

# %% [markdown]
# Мы видим, что игры выпускались с 1980 года. Но для исследования старые данные ничего не дадут, они неактуальны на текущий момент, тем более если мы хотим описать типичного пользователя игр. Поэтому использовать данные нужно за последние годы. Видим, что пик продаж приходится на 2008 - 2009 годы. Это связано с повышением доступности ПК и быстрым развитием индустрии игр. Со временем это спрос идет на спад.\
# Для того, чтобы исследование было достоверным, можно будет использовать данные после 2013 года - они будут актульны.

# %%
na = df.pivot_table(index = 'year_of_release', values = 'na_sales', aggfunc = 'sum').plot(
    kind = 'bar', title = 'Количество продаж в Северной Америке')
plt.xlabel('Год')
plt.ylabel('Количество проданных игр')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Код очень длинный (а PEP8 определяет длину строки в 79 символов) - попробуй длинные - переносить, а между строками использовать пустые строки. Ну и желательно код комментировать, хотя бы коротко (что делаешь и каков будет результат - так твоим коллегам будет проще за твоей мыслью следить). Этот комментарий может относиться к нескольким ячейкам этой «тетрадки».
#
# Хороший разработчик форматирует и комментирует свой код, тогда другие разработчики быстрее разберутся в программе. Это важно, ведь код чаще читают, чем пишут: напишет один, а прочтут — сотни или тысячи (если код хороший).
# «Пишите код так, как будто сопровождать его будет склонный к насилию психопат, который знает, где вы живете.» ©1991, John F. Woods, разработчик
#
# ---
# Давай обсудим стиль кодирования (программирования)? Смотри что сейчас происходит в этой ячейке (**возможно не всё применимо к твоему коду здесь, но я попытался вспомнить все часто встречающиеся недочёты**), что "режет" глаз и что можно сделать по-другому, чуть лучше:
#
# 1. Комментарии к строке кода: они должны располагаться выше соответствующей строки кода (выше строки к которой относятся) и должны быть от этой строки отделены пустой строкой. Если же они расположены справа, то для того чтобы увидеть, что там написано приходится пользоваться скроллиногом. Надо добиться того, чтобы ячейку не приходилось прокручивать, т.к. это не добавляет удобства ни при отладке кода, ни для понимания что в этой ячейке "происходит". Как альтернатива – комментарий может размещаться выше, в Markdown-ячейке.
#
# 2. Бывает, что встречаются очень длинные строки кода, которые также уходят за правый край ячейки. Такие строки должны разбиваться разделителем (вот таким: \\). Это best practice, требование PEP8, а именно: PEP8 определяет длину строки в 79 символов.
#
# 3. **В идеале**: одна ячейка - одна строка кода. Почему так? Да как минимум из соображения понятности: будучи выполненной, под этой ячейкой должен отображаться результат трансформации данных. Ты или твой коллега должны видеть, как поменялись данные после выполнения ячейки с кодом. Следующая ячейка - ещё строка кода и соответствующим output'ом. Будешь делать так - коллеги будут тебе благодарны за то, что легко будут следовать за твоей мыслью. И отладку это упрощает. Ну и как противоположность - можно в одну ячейку "положить" результат 3-х последовательных groupby + ещё чего-нибудь. Разобраться с ходу "что происходит" будет очень трудно, придётся всё равно код разносить по ячейкам и смотреть последовательно что происходит. Но ведь логично это делать удобным способом сразу, ведь так?
#
# 4. Неиспользуемые, закомментированные строки выше вынеси в другую ячейку, отдельную, выше. Можешь для удобства своего прокомментировать (на память). И оставь там это код, так, чтобы он не смешивался с рабочим кодом.
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Всё поняла. Буду следовать этим правилам, чтобы код было легче читать. </font>
# </div>

# %% [markdown]
# Северная Америка - это лидер по продажам. Высокие значения наблюдаются в 2008-2010 годах. Максимальное значение продаж за год в 2008 году приближается к 350 млн. Причем распределение похоже на нормальное, но скошенное слева (что тоже логично, потому что в самом зарождении игровой индуустрии были совсем небольшие продажи - малое количество игр + малый спрос на них).

# %%
eu = df.pivot_table(index = 'year_of_release', values = 'eu_sales', aggfunc = 'sum').plot(
    kind = 'bar', title = 'Динамика продаж в Европе')
plt.xlabel('Год')
plt.ylabel('Сумма продаж игр')
plt.show()

# %% [markdown]
# Европа идет вторым по продажам регионом, но заметно проигрывает Северной Америке. Пики в Европе приходятся тоже на 2008-2010 годы, потом начинается снижение.

# %%
jp = df.pivot_table(index = 'year_of_release', values = 'jp_sales', aggfunc = 'sum').plot(
    kind = 'bar', title = 'Количество продаж в Японии')
plt.xlabel('Год')
plt.ylabel('Количество проданных игр')
plt.show()

# %% [markdown]
# Количество продаж в Японии стоит на третьем месте. Но это обусловлено и меньшей численностью населения в этой стране. Наблюдается плавное нарастание продаж игр по десятилетиям с небольшими спадами, после которых снова начинался подъём.

# %% [markdown]
# Актуальным периодом для прогнозирования на 2017 год выберем данные после 2013 года.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Правильный выбор диапазона!
#
# Это на самом деле один из подводных камней этого проекта!
#
# Студенты могут выбирать для анализа очень большой интервал данных, но для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-4 года. И в такой динамично меняющейся индустрии, как компьютерные игры также не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. В нашем учебном проекте, я с тобой соглашусь, что 4 года: 2013 - 2015 + неполный 2016 - ОК.</div>

# %%
data = df.query('year_of_release > 2012').copy()

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Очень хорошо, что результат запроса/’среза’ ты присваиваешь новому датафрейму. Таким образом оригинальный датафрейм ты оставляешь нетронутым, не перезаписываешь (вдруг нам опять понадобятся данные из него чуть ниже). Это верное решение. Best practice. Молодец!</div>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2233 entries, 16 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             2233 non-null   object
#  1   platform         2233 non-null   object
#  2   year_of_release  2233 non-null   float64
#  3   genre            2233 non-null   object
#  4   na_sales         2233 non-null   float64
#  5   eu_sales         2233 non-null   float64
#  6   jp_sales         2233 non-null   float64
#  7   other_sales      2233 non-null   float64
#  8   critic_score     2233 non-null   float64
#  9   user_score       2233 non-null   float64
#  10  rating           2233 non-null   object
#  11  sales_total      2233 non-null   float64
# dtypes: float64(8), object(4)
# memory usage: 226.8+ KB

# %%
pd.DataFrame(round(data.isna().mean(),5)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_624e0_row0_col0,#T_624e0_row1_col0,#T_624e0_row2_col0,#T_624e0_row3_col0,#T_624e0_row4_col0,#T_624e0_row5_col0,#T_624e0_row6_col0,#T_624e0_row7_col0,#T_624e0_row8_col0,#T_624e0_row9_col0,#T_624e0_row10_col0,#T_624e0_row11_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }</style><table id="T_624e0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_624e0_level0_row0" class="row_heading level0 row0" >name</th>
#                         <td id="T_624e0_row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_624e0_level0_row1" class="row_heading level0 row1" >platform</th>
#                         <td id="T_624e0_row1_col0" class="data row1 col0" >0.000000</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# Пропусков нет, поэтому можно работать с этими данными.

# %% [markdown]
# ### Ответы на вопросы исследования

# %% [markdown]
# #### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %%
sales_by_platform = data.pivot_table(index = 'platform', values = 'sales_total', aggfunc = 'sum').sort_values(
    by=['sales_total'], ascending=False)
sales_by_platform.plot(kind = 'bar', figsize=[20, 10], 
                       title = 'Суммарные продажи игр в зависимости от платформ за 2013-2016 гг.')
plt.xlabel('Платформа')
plt.ylabel('Суммарное значение продаж игр')
plt.show()
plt.show()

# %% [markdown]
# За 2013-2016 годы лидируют по суммарным продажам такие платформы как PS4, PS3, XOne, 3DS. А вот низкие продажи наблюдаются у PSP, DS, Wii, PSV.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# График выглядел бы лучше, если бы "столбики" платформ располагались бы слева-направо в порядке убывания (для этого нужно результат pivot_table отсортировать: sort_values(by=['sales_total'], ascending=False)
#
# p.s. строй графики (и этот и все прочие в этом проекте) крупнее (используй например **figsize=[20, 10]**)</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Добавила сюда еще сравнение по медианному значению продаж. Это позволит посмотреть, на каких платформах в целом более успешные продажи. Потому что высокий показатель суммарных продаж может быть вызван чрезмерно большими продажами каких-то самых популярных игр (которые скорее исключение, чем правило) </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, отлично. Медианные или средние продажи - это верный способ определения стабльных "больших" продаж.
# </div>

# %%
sales_by_platform = data.pivot_table(index = 'platform', values = 'sales_total', aggfunc = 'median').sort_values(
    by=['sales_total'], ascending=False)
sales_by_platform.plot(kind = 'bar', figsize=[20, 10], 
                       title = 'Медианные продажи игр в зависимости от платформ за 2013-2016 гг.')
plt.xlabel('Платформа')
plt.ylabel('Медианное значение продаж игр')
plt.show()

# %% [markdown]
# А вот по медианному значению продаж лидируют платформы X360, XOne и только на 3-ем месте располагается PS4. А вот DS был аутсайдером по суммарным продажам, но по медианному значению продаж оказался на 6 месте! Значит данная платформа пользуется спросом.

# %%
sales_by_year = data.pivot_table(index = 'year_of_release', 
                                 columns = 'platform', values = 'sales_total', aggfunc = 'sum')
sales_by_year.plot()
plt.title('Динамика суммарных продаж игр по платформам')
plt.xlabel('Год')
plt.ylabel('Сумма продаж')
plt.show()

# %%
sales_by_year = data.pivot_table(index = 'year_of_release', 
                                 columns = 'platform', values = 'sales_total', aggfunc = 'median')
sales_by_year.plot(figsize = [15, 8])
plt.title('Динамика медианных продаж игр по платформам')
plt.xlabel('Год')
plt.ylabel('Значения продаж')
plt.show()

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Дополнила вывод </font>
# </div>

# %% [markdown]
# В последние годы многие платформы имют схожие медианные продажи по играм. В последние 1,5 года лидирует WiiU и Wii. То есть они подходят для получения стабильного дохода от продаж игр. А вот медианны продажи у платформы PS4 резко снизились и, возможно, будут снижаться и дальше. Неплохие результаты по медианному показателю у 3DS.\
# Поэтому лидеры по суммарным продажам PS4 и XOne являются таковыми только из-за продаж очень популярных игр. В остальном - их медианные продажи уступают менее популярным плаформам.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Попробуй передвинуть "легенду" вправо, **за** график, чтобы она его не перекрывала. Статья на тему: https://devpractice.ru/matplotlib-lesson-3-1-work-with-legend/
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Попыталась это сделать, но выдаёт "No handles with labels found to put in legend." </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Не должно быть такого. Пример ниже.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>**КОД РЕВЬЮЕРА. НАЧАЛО**</b></div>

# %%
sales_by_year = data.pivot_table(index = 'year_of_release', 
                                 columns = 'platform', values = 'sales_total', aggfunc = 'median')
sales_by_year.plot(figsize = [15, 8])
plt.title('Динамика медианных продаж игр по платформам')
plt.xlabel('Год')
plt.ylabel('Значения продаж')
plt.legend(bbox_to_anchor=(1, .5))
plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <b>**КОД РЕВЬЮЕРА. КОНЕЦ**</b></div>

# %% [markdown]
# Тут уже видна динамика по годам. Есть платформы, которые только недавно появились, но сейчас на них растет активность - это PS4 и XOne. Так как данные за 2016 год непольные, то спад, который показывают графики, может не быть спадом (возможно в 2016 году у данных платформах тоже есть рост).\
# А есть платформы, где продажи стремительно снижаются - PS3, 3DC и X360. Эти платформы не могут называться перспективными.\
# Потенциально прибыльны PS4 и XOne, они лидируют по активности продаж в последние годы. Также для определения лидерующей платформы в исследовании можно сузить временной период и рассмотреть данные с 2015 года. Что поменяется?

# %%
data2 = df.query('year_of_release > 2014').copy()

# %%
sales_by_platform2 = data2.pivot_table(index = 'platform', values = 'sales_total', aggfunc = 'sum').sort_values(
    by = 'sales_total', ascending = False)
sales_by_platform2.plot(kind = 'bar')
plt.title('Динамика продаж игр по платформам с 2015 года')
plt.xlabel('Год')
plt.ylabel('Значения продаж')
plt.show()

# %% [markdown]
# Очень большие суммарные продажи у PS4, а на втором месте будет XOne.

# %% [markdown]
# #### Построение графика «ящик с усами» по глобальным продажам игр в разбивке по платформам.

# %% [markdown]
# Сначала построим "ящик с усами" по глобальным продажам.

# %%
global_sales = data.boxplot('sales_total', figsize=(7,7)).set_ylim(0, 1)
plt.title('Ящик с усами по глобальным продажам')
plt.xlabel('Год')
plt.ylabel('Значения продаж')
plt.show()

# %% [markdown]
# Видим, что медианное значение продаж от той или иной игры составляет около 0.1 млн.

# %% [markdown]
# Дальше построим «ящик с усами» по продажам игр в разбивке по платформам.

# %%
boxplot = data.boxplot(column='sales_total', by='platform', figsize=(10,10)).set_ylim(0,1)
plt.title('Ящик с усами по продажам в разбивке по платформам')
plt.xlabel('Год')
plt.ylabel('Значения продаж')
plt.show()

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Добавила вывод  </font>
# </div>

# %% [markdown]
# Как мы видим, медианные продажи по каждом платформе сильно ниже тех значений, которые признаются выбросами. То есть иногда выпускаются игры, которые дают сильные скачки продаж. Но обычно - игры имеют относительно невысокие доходы по своим продажам.\
# Если сравнивать с медианным значения по глобальным продажам (которое составило около 0.1 млн), то на платформах X360 и XOne оно больше более чем в 2 раза, а на платформах PS4 и WiiU оно примерно в 2 раза больше медианы по глобальным продажам. Значит, на эти платформы стоит обратить внимание, потому что они могут быть более успешными для будущих продаж.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# К сожалению, на этом графике **уверенно** сравнивать квартили (медиану, 25ый и 75ый) у части платформ не получается. Велика вероятность ошибки. Для более обоснованных выводов на основе **только графика** (иначе зачем такой **неговорящий график нужен**) нужно сделать дополнительный график, где будет отображена только нижняя часть boxplot-ов. Этого можно добиться, например, задав параметр ylim
#
# То есть, я бы предложил после этого графика ещё один построить, в котором бы сами "ящики" были лучше видны. На том, что выше выбросы их фактически "забили". Попробуй использовать в параметре ylim, значение, которое ещё больше ограничит значение по OY "сверху" (например, ylim(0, 0.85).
#
# Ну а в твоем случае, из-за того, что на графике не разобрать квартили - для точного сравнения "ящиков" мы вынуждены будем использовать describe().</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Исправила данный момент.  </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, теперь здорово! Теперь «ящики» платформ можно визуально сравнивать между собой прямо на графике.
# </div>

# %% [markdown]
# Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %%
critic_score = data[data['critic_score'] != -1]
user_score = data[data['user_score'] != -1]

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Молодец! Используя (user_score != -1) и (critic_score != -1) ты даешь мне понять, что факт заполнения пропусков "заглушкой" в оценках критиков и пользователей не забыт. Очень грамотно!</div>

# %% [markdown]
# Надо очистить от значений -1, так как если они будут, то корреляция будет выше за счёт одинаковых значений

# %%
corr_df = pd.DataFrame()
corr_df['critic_score'] = critic_score['critic_score']
corr_df['user_score'] = user_score['user_score']

# %%
corr = corr_df[['critic_score', 'user_score']].corr()
corr
# Out:
#               critic_score  user_score
# critic_score      1.000000    0.502221
# user_score        0.502221    1.000000

# %% [markdown]
# Можно заметить, что корреляция между оценками критиков и оценками пользователей не очень высокая. Обычно, оценки должны совпадать, если мнения сторон являются объективными. Но та как есть разница междц оценками, то нельзя точно сказать, кто даёт искаженное мнение об игре. Кто-то может завышать оценки, а кто-то занижать.

# %% [markdown]
# #### Внутри одной популярной платформы (PS4)

# %%
ps4 = data[data['platform'] == 'PS4']
ps4.head()
# Out:
#                               name platform  year_of_release    genre  \
# 31       Call of Duty: Black Ops 3      PS4           2015.0  Shooter
# 42              Grand Theft Auto V      PS4           2014.0   Action
# 77                         FIFA 16      PS4           2015.0   Sports
# 87    Star Wars Battlefront (2015)      PS4           2015.0  Shooter
# 92  Call of Duty: Advanced Warfare      PS4           2014.0  Shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 31      6.03      5.86      0.36         2.38          -1.0        -1.0
# 42      3.96      6.31      0.38         1.97          97.0         8.3
# 77      1.12      6.12      0.06         1.28          82.0         4.3
# 87      2.99      3.49      0.22         1.28          -1.0        -1.0
# 92      2.81      3.48      0.14         1.23          83.0         5.7
#
#        rating  sales_total
# 31  no_rating        14.63
# 42          M        12.62
# ...

# %%
critic_sc = ps4[ps4['critic_score'] != -1]

# %%
user_sc = ps4[ps4['user_score'] != -1]

# %%
## не понимаю как сделать, чтобы корреляция была только по одной платформе

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# **не понимаю как сделать, чтобы корреляция была только по одной платформе** - оставь во временном датафрейме только платформы PS4 и строки без "заглушек" в оценках пользователей (с критиками также поступи). Потом используй метод corr() между 2мя "сериями" (оценки пользователей и продажи).
# </div>

# %% [markdown]
# Посмотрим на отзывы пользователей и их зависимость с продаваемостью игр.

# %% [markdown]
# <div class="alert alert-danger">
# <b>**КОД РЕВЬЮЕРА. НАЧАЛО**</b></div>

# %%
ps4_tmp_us = data[(data['platform'] == 'PS4') & (data['user_score'] != -1)]

ps4_tmp_us.head()
# Out:
#                                name platform  year_of_release         genre  \
# 42               Grand Theft Auto V      PS4           2014.0        Action
# 77                          FIFA 16      PS4           2015.0        Sports
# 92   Call of Duty: Advanced Warfare      PS4           2014.0       Shooter
# 94                          FIFA 17      PS4           2016.0        Sports
# 105                       Fallout 4      PS4           2015.0  Role-Playing
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 42       3.96      6.31      0.38         1.97          97.0         8.3
# 77       1.12      6.12      0.06         1.28          82.0         4.3
# 92       2.81      3.48      0.14         1.23          83.0         5.7
# 94       0.66      5.75      0.08         1.11          85.0         5.0
# 105      2.53      3.27      0.24         1.13          87.0         6.5
#
#     rating  sales_total
# 42       M        12.62
# ...

# %%
ps4_tmp_us.shape
# Out:
# (257, 12)

# %%
ps4_tmp_us['user_score'].corr(ps4_tmp_us['sales_total'])
# Out:
# -0.031957110204556376

# %% [markdown]
# <div class="alert alert-danger">
# <b>**КОД РЕВЬЮЕРА. КОНЕЦ**</b></div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Спасибо за код, ты очень мне помог, а то я ломала голову ♡ Добавила вывод к пользователям. И добила корреляцию с критиками и продажами.  </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# +
# </div>

# %% [markdown]
# Мы видим, что зависимости нет (по модулю корреляция близка к нулю). Причем корреляция даже приняла отрицательное значение. Скорее всего на наиболее продаваемые игры пользователи оставляют более низкие оценки. Потому что пользователей больше - больше риск получить плохую оценку.

# %% [markdown]
# Посмотрим на отзывы пользователей и их зависимость с продаваемостью игр.

# %%
ps4_tmp_cr = data[(data['platform'] == 'PS4') & (data['critic_score'] != -1)]

ps4_tmp_cr.head()
# Out:
#                                name platform  year_of_release         genre  \
# 42               Grand Theft Auto V      PS4           2014.0        Action
# 77                          FIFA 16      PS4           2015.0        Sports
# 92   Call of Duty: Advanced Warfare      PS4           2014.0       Shooter
# 94                          FIFA 17      PS4           2016.0        Sports
# 105                       Fallout 4      PS4           2015.0  Role-Playing
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 42       3.96      6.31      0.38         1.97          97.0         8.3
# 77       1.12      6.12      0.06         1.28          82.0         4.3
# 92       2.81      3.48      0.14         1.23          83.0         5.7
# 94       0.66      5.75      0.08         1.11          85.0         5.0
# 105      2.53      3.27      0.24         1.13          87.0         6.5
#
#     rating  sales_total
# 42       M        12.62
# ...

# %%
ps4_tmp_cr.shape
# Out:
# (252, 12)

# %%
ps4_tmp_us['critic_score'].corr(ps4_tmp_us['sales_total'])
# Out:
# 0.3504074587850579

# %% [markdown]
# А вот тут зависимость пусть и несильная, но присутствует между тем, какие отзывы оставляют критики и то, как продаются игры. В принципе это логично, поскольку часть пользователей может купить игру, если на неё есть отзыв критика, особенно, если он положительный.

# %%
ps4 = data[(data['platform'] == 'PS4') & (data['user_score'] != -1) & (data['critic_score'] != -1)]

# %%
ps4.plot(x='user_score', y='sales_total', kind='scatter', alpha=0.5) 
plt.title('Зависимость оценок пользователей и суммарных продаж игр на PS4')
plt.xlabel('Оценки пользователей')
plt.ylabel('Суммарные продажи игр')
plt.show()

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Немного не понимаю, по коэффициенту корреляция около нуля. А на графике точки имеют какую-то зависимость. Что делать?  </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# **А на графике точки имеют какую-то зависимость. Что делать?** - верить своему коду и графикам, Мария ))) На самом деле я бы не дал голову на отсечение, что какая-то сильная линейная зависимость наблюдается на графике ... Точки достаточно хаотично разбросаны на нем.
# </div>

# %%
ps4.plot(x='critic_score', y='sales_total', kind='scatter', alpha=0.5) 
plt.title('Зависимость оценок критиков и суммарных продаж игр на PS4')
plt.xlabel('Оценки критиков')
plt.ylabel('Суммарные продажи игр')
plt.show()

# %% [markdown]
# Видим положительную зависимость между отзывами критиков и суммарными продажами.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Здесь, на графике, ты не убрал "заглушки" == -1
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Убрала заглушки с графика  </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# +
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# По условию задачи надо сравнить результаты PS4 (то, что сделано выше) с результатами на других консолях. Рассмотри ещё пару консолей отдельно друг от друга. Выводы, сделанные на основе расчетов по нескольким платформам, выглядят "весомей" и убедительней.</div>

# %% [markdown]
# #### Рассмотрим консоль X360

# %% [markdown]
# Пользователи, посмотрим сначала на связь их отзывов и продаж игр

# %%
x360_us = data[(data['platform'] == 'X360') & (data['user_score'] != -1)]

x360_us.head()
# Out:
#                                name platform  year_of_release    genre  \
# 23               Grand Theft Auto V     X360           2013.0   Action
# 60             Call of Duty: Ghosts     X360           2013.0  Shooter
# 263  Call of Duty: Advanced Warfare     X360           2014.0  Shooter
# 271                         FIFA 14     X360           2013.0   Sports
# 380                   Battlefield 4     X360           2013.0  Shooter
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 23       9.66      5.14      0.06         1.41          97.0         8.1
# 60       6.73      2.56      0.04         0.91          73.0         2.6
# 263      2.77      1.11      0.00         0.40          -1.0         4.9
# 271      0.92      2.89      0.01         0.40          84.0         4.2
# 380      2.15      1.01      0.02         0.31          79.0         5.6
#
#     rating  sales_total
# 23       M        16.27
# 60       M        10.24
# ...

# %%
x360_us.shape
# Out:
# (143, 12)

# %%
x360_us['user_score'].corr(x360_us['sales_total'])
# Out:
# -0.011742185147181342

# %%
x360 = data[(data['platform'] == 'X360') & (data['user_score'] != -1)]

# %%
x360.plot(x='user_score', y='sales_total', kind='scatter', alpha=0.5) 
plt.title('Зависимость оценок пользователей и суммарных продаж игр на X360')
plt.xlabel('Оценки пользователей')
plt.ylabel('Суммарные продажи игр')
plt.show()

# %% [markdown]
# Связь между отзывами пользователей и продажами отсутствует.

# %% [markdown]
# Теперь посмотрим на отзывы критиков и их зависимость с продажами

# %%
x360_cr = data[(data['platform'] == 'X360') & (data['critic_score'] != -1)]

x360_cr.head()
# Out:
#                                 name platform  year_of_release    genre  \
# 23                Grand Theft Auto V     X360           2013.0   Action
# 60              Call of Duty: Ghosts     X360           2013.0  Shooter
# 271                          FIFA 14     X360           2013.0   Sports
# 380                    Battlefield 4     X360           2013.0  Shooter
# 410  Assassin's Creed IV: Black Flag     X360           2013.0   Action
#
#      na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 23       9.66      5.14      0.06         1.41          97.0         8.1
# 60       6.73      2.56      0.04         0.91          73.0         2.6
# 271      0.92      2.89      0.01         0.40          84.0         4.2
# 380      2.15      1.01      0.02         0.31          79.0         5.6
# 410      1.90      1.11      0.01         0.29          86.0         7.9
#
#     rating  sales_total
# 23       M        16.27
# 60       M        10.24
# ...

# %%
x360_cr.shape
# Out:
# (81, 12)

# %%
x360_cr['critic_score'].corr(x360_cr['sales_total'])
# Out:
# 0.3503445460228664

# %% [markdown]
# А вот связь между отзывами критиков и продажами имеется, но не очень сильная.

# %%
x360 = data[(data['platform'] == 'X360') & (data['critic_score'] != -1)]

# %%
x360.plot(x='critic_score', y='sales_total', kind='scatter', alpha=0.5) 
plt.title('Зависимость оценок критиков и суммарных продаж игр на X360')
plt.xlabel('Оценки критиков')
plt.ylabel('Суммарные продажи игр')
plt.show()

# %% [markdown]
# #### Рассмотрим консоль WiiU

# %%
wiiu_us = data[(data['platform'] == 'WiiU') & (data['critic_score'] != -1)]

wiiu_us.head()
# Out:
#                      name platform  year_of_release     genre  na_sales  \
# 110          Mario Kart 8     WiiU           2014.0    Racing      3.15
# 247              Splatoon     WiiU           2015.0   Shooter      1.54
# 260  Super Mario 3D World     WiiU           2013.0  Platform      2.11
# 424     Super Mario Maker     WiiU           2015.0  Platform      1.18
# 720     New Super Luigi U     WiiU           2013.0  Platform      1.25
#
#      eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 110      2.15      1.28         0.51          88.0         9.1      E
# 247      1.18      1.46         0.26          81.0         8.5   E10+
# 260      1.16      0.73         0.32          93.0         9.0      E
# 424      0.89      0.94         0.20          88.0         8.7      E
# 720      0.62      0.18         0.18          77.0         7.9      E
#
#      sales_total
# 110         7.09
# 247         4.44
# 260         4.32
# 424         3.21
# 720         2.23

# %%
wiiu_us.shape
# Out:
# (70, 12)

# %%
wiiu_us['user_score'].corr(wiiu_us['sales_total'])
# Out:
# 0.3586664814609293

# %% [markdown]
# А вот на этой платформе связь между отзывами пользователей и продажами существенная. Может быть, пользователи менее придирчивы или ставят более честные оценки и не занижают их.

# %%
wiiu_us = data[(data['platform'] == 'WiiU') & (data['user_score'] != -1)]

# %%
x360.plot(x='user_score', y='sales_total', kind='scatter', alpha=0.5) 
plt.title('Зависимость оценок пользователей и суммарных продаж игр на WiiU')
plt.xlabel('Оценки пользователей')
plt.ylabel('Суммарные продажи игр')
plt.show()

# %%
wiiu_cr = data[(data['platform'] == 'WiiU') & (data['critic_score'] != -1)]

wiiu_cr.head()
# Out:
#                      name platform  year_of_release     genre  na_sales  \
# 110          Mario Kart 8     WiiU           2014.0    Racing      3.15
# 247              Splatoon     WiiU           2015.0   Shooter      1.54
# 260  Super Mario 3D World     WiiU           2013.0  Platform      2.11
# 424     Super Mario Maker     WiiU           2015.0  Platform      1.18
# 720     New Super Luigi U     WiiU           2013.0  Platform      1.25
#
#      eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 110      2.15      1.28         0.51          88.0         9.1      E
# 247      1.18      1.46         0.26          81.0         8.5   E10+
# 260      1.16      0.73         0.32          93.0         9.0      E
# 424      0.89      0.94         0.20          88.0         8.7      E
# 720      0.62      0.18         0.18          77.0         7.9      E
#
#      sales_total
# 110         7.09
# 247         4.44
# 260         4.32
# 424         3.21
# 720         2.23

# %%
wiiu_cr.shape
# Out:
# (70, 12)

# %%
wiiu_cr['critic_score'].corr(wiiu_cr['sales_total'])
# Out:
# 0.3764149065423912

# %% [markdown]
# Связь между отзывами критиков и продажами снова есть, но не очень большая. То есть для каких-то отдельных игр с большими продажами есть положительные отзывы критиков и наборот, с небольшими продажами - есть отрицательные отзывы.

# %%
wiiu_cr = data[(data['platform'] == 'WiiU') & (data['critic_score'] != -1)]

# %%
wiiu_cr.plot(x='critic_score', y='sales_total', kind='scatter', alpha=0.5) 
plt.title('Зависимость оценок критиков и суммарных продаж игр на WiiU')
plt.xlabel('Оценки критиков')
plt.ylabel('Суммарные продажи игр')
plt.show()

# %% [markdown]
# #### Общий вывод:
# На популярных по продажам платформах нет зависимости между отзывами критиков и тем, насколько большие продажи игр. А вот наименее популярные платформы как WiiU показывает, что отзывы пользователей всё таки взаимосвязаны с продажами игр.\
# Если же говорить о критиках, то вне зависимости от платформы их взамосвязь между продажами существует примерно в равной степени на разных платформах. Поэтому есть шанс, что если игра имеет хорошую оценку критика, то она продаётся лучше. Но есть шанс, что продажи могут повляить на отзыв критика (критический отзыв также может быть проплачен компанией, выпускающей игры или самой платформой для роста продаж)

# %% [markdown]
# ####  Общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
data.pivot_table(index = 'genre', values = 'sales_total', aggfunc = 'median').sort_values(
    by = 'sales_total', ascending = False).plot(
    kind = 'bar', legend = False, title = 'Распределение игр по жанрам за 2013-2016 гг.')
plt.xlabel('Название жанра игры')
plt.ylabel('Медианные продажи')
plt.show()

# %% [markdown]
# Самые популярные среди пользователей за 2013-2016 годы - это игры в жанре Шуттер (стрелялки). На втором месте идут спортивные игры. Экшн-игры, которые лидируют по своему количеству на рынке не могут назваться востребованными среди пользователей - их медианные продажи невысоки. Самые непопулярные игры - это пазлы и приключения. Вероятно, спрос на подобные жанры низкий.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Здесь у нас возникла проблема: по суммарным (sum, count) объемам продаж у тебя получилось, что явный лидер - игры в жанре Экшн. Если же ты рассмотришь медианные или средние (mean) значения, то результат поменяется в пользу Шуттеров. Учти тот факт, что игр в жанре Экшн выпускается значительно больше, чем других (в 1,5-2 раза). Доля количества игр в жанре «стрелялок» - всего лишь 8%. Очевидно, что в жанре Экшн присутствует большое количество непопулярных игр с низкими объёмами продаж, в результате чего общий объём продаж жанра "раздут" и берётся количеством, а не качеством. Медиана учитывает не только слишком большие\маленькие значения относительно среднего, но и их количество. Поэтому брать итоговые результаты медианы или среднего более корректно.
#
# В сухом остатке: попробуй рассмотреть не общие продажи, а медианные (или средние). Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние (или медианные продажи). Я думаю, что анализ медианных показателей позволит тебе найти жанр, который приносит высокий доход.
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Поправила на медианное значение и изменила вывод.  </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Да, отлично, теперь самый прибыльный жанр (Шуттеры) определен верно!
# </div>

# %% [markdown]
# ### Составление портрета пользователя каждого региона

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Здесь я тоже изменила на медианное значение и изменила выводы.  </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# +
# </div>

# %% [markdown]
# #### Самые популярные платформы (топ-5)

# %%
data.groupby(by='platform').agg({'na_sales':'sum'}).sort_values(by='na_sales', 
                                                              ascending=False).head(5).plot(
    kind='bar', figsize = (4,4), title = 'Топ-5 платформ в Северной Америке')

plt.xlabel('Название платформы')
plt.ylabel('Суммарные продажи')
plt.show()

# %% [markdown]
# Для американского пользователя предпочтительной платформой для игр является PS4 и XOne, это важно будет при составлении статегии по продажам в этом регионе. Ведь наболее хороший результат по продажам имеют именно эти платформы.

# %%
data.groupby(by='platform').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', 
                                                              ascending=False).head(5).plot(
    kind='bar', figsize = (4,4), title = 'Топ-5 платформ в Европе')

plt.xlabel('Название платформы')
plt.ylabel('Суммарные продажи')
plt.show()

# %% [markdown]
# Для европейского пользователя предпочтительной платформой для игр является PS4, что нужно будет учесть компании, когда она будет прогнозировать продажи на 2017 год в Европе.

# %%
data.groupby(by='platform').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', 
                                                              ascending=False).head(5).plot(
    kind='bar', figsize = (4,4), title = 'Топ-5 платформ в Японии')

plt.xlabel('Название платформы')
plt.ylabel('Суммарные продажи')
plt.show()

# %% [markdown]
# Для японского пользователя предпочтительной платформой для игр является 3DS, это важно будет при составлении статегии по продажам в этом регионе. При этом  продажи игр на PS3 и PSV очень похожи.

# %% [markdown]
# #### Вывод
# Рынки Северной Америки и Европы похожи между собой. А Вот рынок Японии отличается. Поэтому при планировании нельзя будет составить единую стратегию по продажам. Для достижения наибольшего успеха нужно учесть особенности каждого региона и стараться ориентироваться на продажи игр на тех платформах, которые имеют спрос у пользователей страны.

# %% [markdown]
# #### Самые популярные жанры (топ-5)

# %%
data.groupby(by='genre').agg({'na_sales':'sum'}).sort_values(by='na_sales', 
                                                              ascending=False).head(5).plot(
    kind='bar', figsize = (4,4), title = 'Топ-5 жанров в Северной Америке')

plt.xlabel('Название жанра')
plt.ylabel('Суммарные продажи')
plt.show()

# %% [markdown]
# В Северной Америке хорошо продаются игры эшн и стрелялки. Поэтому можно делать хорошие рекламные коампании в этом регионе этих жанров - продажи могут вырасти.

# %%
data.groupby(by='genre').agg({'eu_sales':'median'}).sort_values(by='eu_sales', 
                                                              ascending=False).head(5).plot(
    kind='bar', figsize = (4,4), title = 'Топ-5 жанров в Европе')

plt.xlabel('Название жанра')
plt.ylabel('Суммарные продажи')
plt.show()

# %% [markdown]
# В Европе тоже хорошо продаются игры в жанре шуттер.

# %%
data.groupby(by='genre').agg({'jp_sales':'median'}).sort_values(by='jp_sales', 
                                                              ascending=False).head(5).plot(
    kind='bar', figsize = (4,4), title = 'Топ-5 жанров в Японии')

plt.xlabel('Название жанра')
plt.ylabel('Суммарные продажи')
plt.show()

# %% [markdown]
# В Японии хорошо продаются ролевые игры.

# %% [markdown]
# Лидеры жанров в Северной Америке и в Европе очень схожи: первые четыре позиции занимаются одни и те же жанры. Больше всего игроки из Северной Америки и Европы любят жанр экшy, шутер (стрелялки), спортивные и ролевые. Схожесть этих двух регионов связана с популяризацией западной культуры и формированием массовых интересов у потребителей игр. В Японии же лидируют ролевые игры, потом идут экшн. Видимо японцам больше интересны игры с ролями, чем что-либо другое.

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# В этих 2х подразделах всё отлично! Предпочтения геймеров 3х регионов в отношении игровых платформ и жанров определены. Ну и вывод соответственно описывает эти отличия.</div>

# %% [markdown]
# #### Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
data['rating'].unique()
# Out:
# array(['M', 'no_rating', 'E', 'T', 'E10+'], dtype=object)

# %% [markdown]
# Рейтинг ESRB:\
# M («Mature») — "От 17 лет"\
# E («Everyone») — "Для всех"\
# «E10+» («Everyone 10 and older») «Для всех старше 10 лет»\
# «T» («Teen») — «Подросткам»: Игра подходит для лиц от 13 лет и старше\
# «EC» («Early childhood») — «Для детей младшего возраста»\
# «RP» («Rating Pending»") — «Рейтинг ожидается»

# %%
data.groupby(by='rating').agg({'na_sales':'sum'}).sort_values(by='na_sales', ascending=False).head(5).plot(
    kind='bar', figsize = (4,4), title ='Распределение продаж игр в зависимости от рейтинга ESRB в Северной Америке' )
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Один из подводных камней этого проекта. Суть его в том, что часто студенты в самом начале «тетрадки» пропуски в 'rating' не обрабатывают, оставляют NaN, и соответственно во время анализа и/или построении графиков игры без рейтингов «теряются».</div>

# %% [markdown]
# Наибольшие продажи в Северной Америке приходятся на игры от 17 лет. Что вполне логично, ведь целевая аудитория в Северной Америке - это подростки и молодые люди, спрос которых на игры достаточно высок. Меньше продаж по играм, которые предназначены для всех.

# %%
data.groupby(by='rating').agg({'eu_sales':'sum'}).sort_values(by='eu_sales', ascending=False).head(5).plot(
    kind='bar', figsize = (4,4), title ='Распределение продаж игр в зависимости от рейтинга ESRB в Европе' )
plt.show()

# %% [markdown]
# В Европе также популярными среди продаж идут игры с рейтингом 17+, что аналогично ситуации в Северной Америке. Уже ранее было замечено, что потребители этих рыноков видеоигр схожи.

# %%
data.groupby(by='rating').agg({'jp_sales':'sum'}).sort_values(by='jp_sales', ascending=False).head(5).plot(
    kind='bar', figsize = (4,4), title ='Распределение продаж игр в зависимости от рейтинга ESRB в Японии')
plt.show()

# %% [markdown]
# В Японии ситуация несколько сложнее, так как для большого числа игр не удалось установить рейтинг (там изначально были пропуски). Но популярными здесь являются игры "для всех" и игры для подростков (13+).

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Рейтинг ESRB - это американский рейтинг, а в Японии есть своё рейтинговое агентство (CERO). Получается, что Япония страна со своим менталитетом. И твой анализ показывает, что Японцы в игры-то играют не такие, как весь прочий мир и жанры игр там популярны совсем другие, нежели в остальном мире, да и на рейтинги (не своего агентства) не очень то внимание обращают.</div>

# %% [markdown]
# #### Общий вывод:
# По сути рейтинг влияет, но не сильно. Потому что, например, в Северной Америке и в Европе, активные пользователи игр - это подростки и молодые люди, поэтому они попадают под эту категорию. Но точно сказать, влияет ли рейтинг нельзя, поскольку есть множество факторов, которые тоже влияют на продажи. Игра может быть просто интересной и круто разработанной, поэтому её будут покупать вне зависимости от того, какой рейтинг ESRB был установлен.

# %% [markdown]
# ### Проверка гипотез

# %%
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# Все импорты лучше собрать в самой первой ячейке "тетрадки" с кодом - так твои коллеги с первого взгляда смогут понять и оценить какие библиотеки ты используешь в своём проекте.</div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Ладушки! В следующий раз именно так и сделаю))  </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# +
# </div>

# %% [markdown]
# #### 1 гипотеза

# %% [markdown]
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые - это гипотеза H0\
# H1 - то, что рейтинги разные\
# Пусть уровень статистического значимости = 0.05\
# Эти выборки независимы - те пользователи, кто пользуется Xbox не пересекаются с PC

# %% [markdown]
# Если p> alpha: принять нулевую гипотезу.
# Если p <= alpha: отклоните нулевую гипотезу.

# %%
data['platform'].unique()
# Out:
# array(['PS3', 'X360', 'PS4', '3DS', 'XOne', 'WiiU', 'Wii', 'PC', 'PSV',
#        'DS', 'PSP'], dtype=object)

# %%
data.head()
# Out:
#                          name platform  year_of_release         genre  \
# 16         Grand Theft Auto V      PS3           2013.0        Action
# 23         Grand Theft Auto V     X360           2013.0        Action
# 31  Call of Duty: Black Ops 3      PS4           2015.0       Shooter
# 33        Pokemon X/Pokemon Y      3DS           2013.0  Role-Playing
# 42         Grand Theft Auto V      PS4           2014.0        Action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 23      9.66      5.14      0.06         1.41          97.0         8.1
# 31      6.03      5.86      0.36         2.38          -1.0        -1.0
# 33      5.28      4.19      4.35         0.78          -1.0        -1.0
# 42      3.96      6.31      0.38         1.97          97.0         8.3
#
#        rating  sales_total
# 16          M        21.05
# 23          M        16.27
# ...

# %%
user_xbox = data[(data['platform'] == 'XOne') & (data['user_score'] > 0)]

# %%
user_pc = data[(data['platform'] == 'PC') & (data['user_score'] > 0)]

# %%
alpha = 0.05
results = st.ttest_ind(user_xbox['user_score'], user_pc['user_score'])
print('p-значение:', results.pvalue)

if results.pvalue < alpha: 
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.14012658403611647
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div class="alert alert-success">
# <b>ОТЛИЧНО! 👍</b>
#
# Очень хорошо, что ты не забываешь отфильтровать «заглушки» / NaN значения.
#
# Также верно и то, что мы используем здесь двусторонний тест.
# </div>

# %% [markdown]
# В нашем случае нет оснований для того, чтобы сделать вывод о существовании значимых отличий между средними рейтингами пользователей на платформе Xbox One и на платформе PC.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# Нельзя сделать вывод, что тест "подтвердил" одну из гипотез (в статистике гипотезы подтвердить невозможно) или "подтвердил" равенство/неравенство (можно говорить только о статистически (не)значимом различии). Например так: «У нас нет оснований утверждать, что средние пользовательские рейтинги платформ Xbox One и PC значимо различаются».
#
# И ещё на эту же тему: никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана. Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу. Статья на эту тему: https://allatambov.github.io/psms/pdf/hypo-test.pdf
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Исправила вывод насчёт гипотезы выше. Я была в курсе того, что гипотеза не может подтвердиться, но ну тут написала по-другому. Спасибо тебе))  </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# +
# </div>

# %% [markdown]
# #### 2 гипотеза

# %% [markdown]
# H0: Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») одинаковые.\
# H1: Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.\
# Это тоже независимые выборки

# %%
action_r = data[data['genre'] == 'Action']

# %%
sports_r = data[data['genre'] == 'Sports']

# %%
alpha = 0.05
results = st.ttest_ind(action_r['user_score'], sports_r['user_score'])
print('p-значение:', results.pvalue)

if results.pvalue < alpha: 
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.02193663336455412
# Отвергаем нулевую гипотезу

# %% [markdown]
# В нашем случае есть основания для того, чтобы сделать вывод о существовании значимых отличий между средними пользовательскими рейтингами жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования»).
#
# Возможно, эти жанры отличаются между собой, пользователи дают им разные оценки. Так как в ходе исследования было выявлено, что жанр "экшн" в играх самый популярны среди пользователей Северной Америки и Европы, а Японии он занимает 2 место по продажам. А вот спортивные игры в Северной Америке и Европе занимаются 3 место, а в Японии даже не входят в топ-5. Похоже, спортивные игры не всем по вкусу, что обуславливает различие в оценках.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий 👉</b>
#
# **Всё-таки средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные одинаковые** - какие?
# </div>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Исправила вывод  </font>
# </div>

# %% [markdown]
# ###  Общий вывод

# %% [markdown]
# Для интернет-магазина «Стримчик», который продаёт по всему миру компьютерные игры, для построения прогноза по продажам игр в разные регионы было важно понять, как сильно отличаются продажи в них и насколько разные пользователи между собой.
#
# В ходе исследования мы поняли, что рынок игр Северной Америки очень похож на рынок игр в Европе, что позволит компании строить примерно одинаковую политику по продажам там. А вот к рынку игр Японии нужно будет найти другой подход и предлагать игры, на которые есть спрос. Так как игровая индустрия быстро меняется и меняются платформы на которых играют пользователи, то период для прогноза был выбран с 2013 года. Были определены тендеции продаж последних лет.
#
# Удалось понять то, какие платформы используют в разных регионах и какие жанры лидируют. Также был сделан вывод о зависимости оценок пользователей и критиков на продажи и то, влияет ли рейтинг ESRB на продажи игр. В обоих случаях связь не совсем однозначная, но вот оценки пользователей и критиков, похоже, всё таки влияют на продажи, поэтому на них тоже нужно обратить внимание при работе.
#
# Также важно заметить, что стабильный доход от продаж приносят такие жанры как шуттер, спортивные игры и платформенные игры. У них наблюдаются высокие медианные продажи. В Северной Америки наиболее актуальны и продаваемы
# экшн-игры, в Европе лидируют шуттер игры, а в Японии - ролевые. Есть о чём задуматься для реализации игр в той или иной стране.
#
# Через какую платформу идут продажи? Ответом стало то, что на игровом рынке Северной чаще всего игры продаются через платформу PS4, в Европе тоже через PS4, а вот в Японии через 3DS.

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'> Немного пересмотрела свой вывод  </font>
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>КОММЕНТАРИЙ V2</b>
#
# Отлично, молодец, спасибо!
# </div>

# %% [markdown]
# ### Рекомедации

# %% [markdown]
# Нужно поработать над системой рейтинга оценок пользователей и критиков по играм, чтобы минимизировать пропуски. Возможно после покупки игры и того, как пользователей провёл в ней достаточно времени, предлагать оценить этот продукт на сайте. Можно ввести поощрение за добавление отзывов к играм, что позволит детальнее раскрыть портрет покупателя.
#
# Для рынка Японии стоит сформировать отдельную стратегию по продажам, которая будет учитывать его отличительные особенности. Для Северной Америки и Европы стратегии могут быть похожи.
#
# Для игр с аномально высокими продажами можно сделать свой рейтинг на сайте, типа бестселлеры. А вот чтобы стимулировать рост продаж игр "новичков", которые не сильно раскручены рынком - нужно придумать отдельные рейтинги и рекомедации к их покупке. Потому что пользователи могут не хотеть играть в "очень популярные игры", а им хочется чего-то нового и необычного. Таким образом продвижение новых игр позволит магазину расти в продажах не только по бестселлерам, но и по другим продуктам.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# После исправления красных комментариев надо будет ещё раз пересмотреть выводы в этом финальном разделе, я уверен, что некоторые акценты сместятся и твой вывод поменяется.
# </div>

# %% [markdown]
# # Результат ревью:
#
# Я отмечаю адекватный уровень твоей программистской подготовки. Ты используешь продвинутые концепции языка Python и библиотеки pandas. Всё это в целом упрощает твой код и одновременно показывает твой уровень владения инструментами.
#
# Ты умело применяешь графические библиотеки (matplotlib), выбираешь для визуализации ровно те типы графиков, которые нужны. Если ещё поработать над тем, чтобы все оси были подписаны и графики имели понятные названия, то будет просто отлично.
#
# С комментированием никаких проблем нет. Твоих объяснений достаточно для понимания твоими коллегами хода мыслей. Ссылки из брифа проекта в нужных местах также помогают следовать за развитием событий и дают полную информацию касаемо того, что будет происходить в том или ином разделе проекта.
#
# Мне было просто проверять твой проект, потому что он чётко структурирован, с использованием оглавления.
#
# Зелёным цветом я отметил и прокомментировал удачные и элегантные решения, на которые ты можешь опираться в будущих проектах.
#
# Жёлтым цветом я выделил то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас.
#
# Однако есть принципиальные моменты, которые не позволяют мне принять твой проект в его нынешнем состоянии:
#
# <div class="alert alert-danger">
# <b>Необходимо исправить ❌</b>
#
# 1. В разделе построения «ящика с усами» по глобальным продажам игр в разбивке по платформам необходимо построить график так, чтобы квартили соответствующих «ящиков» позволяли визуально сравнивать платформы между собой. **Все боксплоты** нужно построить на одном графике.
#
# 2. В разделе расчета корреляций между оценками (пользователей/экспертов) и продажами, на графике отрисованы данные содержащие «заглушки» (заполненные руками значения == -1).
#
# 3. По условию задачи надо сравнить результаты PS4 с результатами на других консолях.
#
# 4. Попробуй рассмотреть не общие продажи, а медианные (или средние). Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. Анализ медианных показателей позволит тебе найти жанр, который приносит высокий доход.
#
# 5. Нельзя сделать вывод, что что наш тест "подтвердил" одну из гипотез (в статистике гипотезы подтвердить невозможно) или "подтвердил" равенство/неравенство (можно говорить только о статистически (не)значимом различии).</div>
#
# Эти 5 моментов требуют твоего внимания. Комментарии по ним помечены красным цветом.
#
# Подводя итог: хорошая работа на самом-то деле, молодец! Есть несколько моментов к исправлению, но уверен, что они не вызовут у тебя сложностей. После доработки обязательно проверь комментарии и выводы. Их нужно будет скорректировать. Жду доработанную версию проекта на повторное ревью.
